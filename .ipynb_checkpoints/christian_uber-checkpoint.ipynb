# %%
# !pip install sodapy
# Out:
# Collecting sodapy
#   Downloading sodapy-2.1.0-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: requests>=2.20.0 in c:\users\christian\anaconda3\envs\pythondata\lib\site-packages (from sodapy) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\christian\anaconda3\envs\pythondata\lib\site-packages (from requests>=2.20.0->sodapy) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\christian\anaconda3\envs\pythondata\lib\site-packages (from requests>=2.20.0->sodapy) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\christian\anaconda3\envs\pythondata\lib\site-packages (from requests>=2.20.0->sodapy) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\christian\anaconda3\envs\pythondata\lib\site-packages (from requests>=2.20.0->sodapy) (2.9)
# Installing collected packages: sodapy
# Successfully installed sodapy-2.1.0

# %%
import json
import pandas as pd
from sodapy import Socrata
import requests

# %%
url = "https://data.cityofnewyork.us/resource/2v9c-2k7f"

uber_data = requests.get(url).json()

#response = requests.get(url)
from pprint import pprint

pprint(uber_data)

#response = client.get_user_activity()
#history = response.json
# Out:
# [{'base_license_number': 'B00053',
#   'base_name': 'CHARGE AND RIDE INC',
#   'month': '6',
#   'month_name': 'June',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '681',
#   'unique_dispatched_vehicles': '34',
#   'year': '2019'},
#  {'base_license_number': 'B02699',
#   'base_name': 'PRESIDENTIAL LUXURY LIMO INC.',
#   'month': '7',
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1170',
#   'unique_dispatched_vehicles': '32',
#   'year': '2016'},
#  {'base_license_number': 'B01176',
#   'base_name': 'SANTO DOMINGO CAR LIMO SERVICES INC',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '19429',
#   'unique_dispatched_vehicles': '88',
#   'year': '2015'},
#  {'base_license_number': 'B00837',
#   'base_name': 'CAREY LIMO N Y INC',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '4673',
#   'unique_dispatched_vehicles': '146',
#   'year': '2020'},
#  {'base_license_number': 'B02191',
#   'base_name': 'US LIMO SYSTEM INC',
#   'month': '7',
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '769',
#   'unique_dispatched_vehicles': '27',
#   'year': '2016'},
#  {'base_license_number': 'B01970',
#   'base_name': 'GRAFE STREET SERVICE CORP.',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '482',
#   'unique_dispatched_vehicles': '10',
#   'year': '2017'},
#  {'base_license_number': 'B02641',
#   'base_name': 'AVENUE X CAR SERVICE INC.',
#   'dba': 'PRESTIGE CAR SERVICE',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2465',
#   'unique_dispatched_vehicles': '15',
#   'year': '2019'},
#  {'base_license_number': 'B00225',
#   'base_name': 'DELANCEY TRANSPORTATION INC.',
#   'month': '9',
#   'month_name': 'September',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '22759',
#   'unique_dispatched_vehicles': '123',
#   'year': '2015'},
#  {'base_license_number': 'B01381',
#   'base_name': 'CLASSIC CAR SERVICE CORP.',
#   'dba': 'PAISA CLASSIC',
#   'month': '1',
#   'month_name': 'January',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1631',
#   'unique_dispatched_vehicles': '17',
#   'year': '2020'},
#  {'base_license_number': 'B02965',
#   'base_name': 'ORION LUXURY CORP',
#   'month': '1',
#   'month_name': 'January',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '723',
#   'unique_dispatched_vehicles': '13',
#   'year': '2019'},
#  {'base_license_number': 'B01039',
#   'base_name': 'NYC WHEELS CAR SERVICE INC.',
#   'dba': 'COMMUNICARE CAR SERVICE',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '6064',
#   'unique_dispatched_vehicles': '22',
#   'year': '2018'},
#  {'base_license_number': 'B01362',
#   'base_name': 'AMERICAN BASE NO.1 INC.',
#   'month': '1',
#   'month_name': 'January',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '9162',
#   'unique_dispatched_vehicles': '63',
#   'year': '2018'},
#  {'base_license_number': 'B02717',
#   'base_name': 'ZOOM CAR SERVICE INC.',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '837',
#   'unique_dispatched_vehicles': '3',
#   'year': '2018'},
#  {'base_license_number': 'B02191',
#   'base_name': 'US LIMO SYSTEM INC',
#   'month': '7',
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '282',
#   'unique_dispatched_vehicles': '11',
#   'year': '2019'},
#  {'base_license_number': 'B02857',
#   'base_name': 'MATHES SERVICE INC.',
#   'dba': 'NUNU ROCHDALE CAR SERVICE',
#   'month': '1',
#   'month_name': 'January',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1748',
#   'unique_dispatched_vehicles': '7',
#   'year': '2018'},
#  {'base_license_number': 'B02655',
#   'base_name': 'LONG ISLAND CITY CAR AND LIMO INC.',
#   'dba': 'A2B CORPORATE SEDAN',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '19',
#   'unique_dispatched_vehicles': '6',
#   'year': '2015'},
#  {'base_license_number': 'B01717',
#   'base_name': 'HIGH CLASS BRONX LIMO C/S CORP',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '14897',
#   'unique_dispatched_vehicles': '90',
#   'year': '2019'},
#  {'base_license_number': 'B02641',
#   'base_name': 'AVENUE X CAR SERVICE INC.',
#   'dba': 'PRESTIGE CAR SERVICE',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2375',
#   'unique_dispatched_vehicles': '11',
#   'year': '2017'},
#  {'base_license_number': 'B00271',
#   'base_name': 'UTOG 2-WAY RADIO INC',
#   'dba': 'UTOG CORPORATE CAR SERVICE',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '20106',
#   'unique_dispatched_vehicles': '290',
#   'year': '2016'},
#  {'base_license_number': 'B02308',
#   'base_name': 'NORWOOD CAR & LIMO INC.',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '271',
#   'unique_dispatched_vehicles': '24',
#   'year': '2017'},
#  {'base_license_number': 'B02531',
#   'base_name': 'CLEAN AIR CAR SERVICE AND PARKING CORP.',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '5247',
#   'unique_dispatched_vehicles': '38',
#   'year': '2017'},
#  {'base_license_number': 'B00889',
#   'base_name': 'MEXICANA CAR SERVICE INC.',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '4791',
#   'unique_dispatched_vehicles': '19',
#   'year': '2019'},
#  {'base_license_number': 'B01263',
#   'base_name': "RACHEL'S CAR SERVICE,INC.",
#   'month': '9',
#   'month_name': 'September',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '5243',
#   'unique_dispatched_vehicles': '19',
#   'year': '2017'},
#  {'base_license_number': 'B02671',
#   'base_name': 'COMMUNITY CAR SERVICE PRISCILLA CORP',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '3525',
#   'unique_dispatched_vehicles': '19',
#   'year': '2019'},
#  {'base_license_number': 'B02213',
#   'base_name': 'EXPRESS 11 CAR SERVICE, INC.',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '3703',
#   'unique_dispatched_vehicles': '19',
#   'year': '2017'},
#  {'base_license_number': 'B00095',
#   'base_name': 'LIBERTY CAR SERVICE INC.',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '20826',
#   'unique_dispatched_vehicles': '81',
#   'year': '2015'},
#  {'base_license_number': 'B02917',
#   'base_name': 'C & A BLACK CAR CORP.',
#   'month': '7',
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '207',
#   'unique_dispatched_vehicles': '22',
#   'year': '2018'},
#  {'base_license_number': 'B00937',
#   'base_name': 'RIVERSIDE RADIO DISPATCHER',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '61347',
#   'unique_dispatched_vehicles': '284',
#   'year': '2017'},
#  {'base_license_number': 'B02472',
#   'base_name': 'NEW BUSHWICK LUXURY INC.',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '9379',
#   'unique_dispatched_vehicles': '52',
#   'year': '2017'},
#  {'base_license_number': 'B02553',
#   'base_name': 'NEW JUBILEE CAR SERVICE, INC.',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '5817',
#   'unique_dispatched_vehicles': '53',
#   'year': '2015'},
#  {'base_license_number': 'B02924',
#   'base_name': 'CELEBRITY LUXURY INC.',
#   'month': '9',
#   'month_name': 'September',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '6197',
#   'unique_dispatched_vehicles': '55',
#   'year': '2018'},
#  {'base_license_number': 'B01065',
#   'base_name': "EL BARRIO'S CAR SERVICE LLC",
#   'month': '9',
#   'month_name': 'September',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '7579',
#   'unique_dispatched_vehicles': '52',
#   'year': '2018'},
#  {'base_license_number': 'B02694',
#   'base_name': 'CITY LIMOUSINE TRANSPORTATION INC.',
#   'month': '9',
#   'month_name': 'September',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '135',
#   'unique_dispatched_vehicles': '16',
#   'year': '2015'},
#  {'base_license_number': 'B02426',
#   'base_name': 'TRISTAR SERVICES (US) INC.',
#   'dba': 'TRISTAR WORLDWIDE CHAUFFEURED SERVICES',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1342',
#   'unique_dispatched_vehicles': '26',
#   'year': '2016'},
#  {'base_license_number': 'B00149',
#   'base_name': 'RAINBOW RAD DISP INC',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1677',
#   'unique_dispatched_vehicles': '15',
#   'year': '2017'},
#  {'base_license_number': 'B02770',
#   'base_name': 'CAVALIER CAR & LIMOUSINE, INC.',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '442',
#   'unique_dispatched_vehicles': '8',
#   'year': '2016'},
#  {'base_license_number': 'B02898',
#   'base_name': 'SANO CAR LLC',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2065',
#   'unique_dispatched_vehicles': '15',
#   'year': '2016'},
#  {'base_license_number': 'B02200',
#   'base_name': 'BCL NETWORK LLC',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '613',
#   'unique_dispatched_vehicles': '28',
#   'year': '2016'},
#  {'base_license_number': 'B01392',
#   'base_name': 'NEW AMERICAN CLASS L/C SERVICE CORP.',
#   'month': '6',
#   'month_name': 'June',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '190',
#   'unique_dispatched_vehicles': '4',
#   'year': '2019'},
#  {'base_license_number': 'B01653',
#   'base_name': "ART'S PLACE INC.",
#   'dba': 'ON TIME CAR SERVICE',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '3002',
#   'unique_dispatched_vehicles': '14',
#   'year': '2015'},
#  {'base_license_number': 'B02709',
#   'base_name': 'DASH CAR SERVICE CORP',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1056',
#   'unique_dispatched_vehicles': '3',
#   'year': '2019'},
#  {'base_license_number': 'B00608',
#   'base_name': 'SUMMIT CORPORATE CAR INC.',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '988',
#   'unique_dispatched_vehicles': '25',
#   'year': '2019'},
#  {'base_license_number': 'B01455',
#   'base_name': 'REPUBLICA CAR & LIMO SERVICE CORP.',
#   'month': '7',
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '5590',
#   'unique_dispatched_vehicles': '50',
#   'year': '2016'},
#  {'base_license_number': 'B00375',
#   'base_name': 'THE EXCELLENT C/S INC',
#   'month': '9',
#   'month_name': 'September',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '16035',
#   'unique_dispatched_vehicles': '101',
#   'year': '2015'},
#  {'base_license_number': 'B02102',
#   'base_name': 'GOLDEN DRAGON EXPRESS, INC',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '484',
#   'unique_dispatched_vehicles': '6',
#   'year': '2016'},
#  {'base_license_number': 'B01336',
#   'base_name': 'BAY EXPRESS CORP.',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '5173',
#   'unique_dispatched_vehicles': '29',
#   'year': '2016'},
#  {'base_license_number': 'B02315',
#   'base_name': 'LA MORENITA CAR LIMO SERVICE INC',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2330',
#   'unique_dispatched_vehicles': '8',
#   'year': '2019'},
#  {'base_license_number': 'B02770',
#   'base_name': 'CAVALIER CAR & LIMOUSINE, INC.',
#   'month': '7',
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '234',
#   'unique_dispatched_vehicles': '12',
#   'year': '2015'},
#  {'base_license_number': 'b01109',
#   'base_name': 'UNITED EXP C/L SVCE',
#   'month': '7',
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '11705',
#   'unique_dispatched_vehicles': '57',
#   'year': '2016'},
#  {'base_license_number': 'LYFT',
#   'base_name': 'LYFT',
#   'dba': 'LYFT',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1619126',
#   'unique_dispatched_vehicles': '21715',
#   'year': '2017'},
#  {'base_license_number': 'B01194',
#   'base_name': '440 CAR SERVICE INC.',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1697',
#   'unique_dispatched_vehicles': '7',
#   'year': '2019'},
#  {'base_license_number': 'B01742',
#   'base_name': 'AVALON TRANSPORTATION, LLC',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '332',
#   'unique_dispatched_vehicles': '13',
#   'year': '2018'},
#  {'base_license_number': 'B02330',
#   'base_name': 'OCHO LUXURY CAR, INC.',
#   'dba': 'ACAPOLCO EXPRESS',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1064',
#   'unique_dispatched_vehicles': '6',
#   'year': '2017'},
#  {'base_license_number': 'B01629',
#   'base_name': 'BBA MANAGEMENT INC.',
#   'dba': 'UNITED CAR & LIMO SERVICE',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2100',
#   'unique_dispatched_vehicles': '12',
#   'year': '2016'},
#  {'base_license_number': 'B02532',
#   'base_name': 'COZY RIDE LIMOUSINE INC',
#   'dba': 'COZY TRANSIT',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '401',
#   'unique_dispatched_vehicles': '11',
#   'year': '2020'},
#  {'base_license_number': 'B02740',
#   'base_name': 'MAZAL LIMOUSINE SERVICE INC',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '182',
#   'unique_dispatched_vehicles': '5',
#   'year': '2016'},
#  {'base_license_number': 'B02851',
#   'base_name': 'GALLANT CAR SERVICE CORP.',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '122',
#   'unique_dispatched_vehicles': '1',
#   'year': '2018'},
#  {'base_license_number': 'B02346',
#   'base_name': 'PIA CAR LIMO. INC.',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '21',
#   'unique_dispatched_vehicles': '2',
#   'year': '2019'},
#  {'base_license_number': 'B00448',
#   'base_name': 'DIAL CAR INC.',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '170',
#   'unique_dispatched_vehicles': '23',
#   'year': '2015'},
#  {'base_license_number': 'B03018',
#   'base_name': 'AUREUS LLC',
#   'dba': 'JAVA CAR & LIMOUSINE SERVICE',
#   'month': '8',
#   'month_name': 'August',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '27',
#   'unique_dispatched_vehicles': '1',
#   'year': '2019'},
#  {'base_license_number': 'B00827',
#   'base_name': 'CASTLE CAR SERVICE, INC',
#   'month': '8',
#   'month_name': 'August',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '756',
#   'unique_dispatched_vehicles': '3',
#   'year': '2019'},
#  {'base_license_number': 'B01309',
#   'base_name': 'ACME LIMOUSINE LLC',
#   'dba': 'ARROW TRANSPORTATION',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '352',
#   'unique_dispatched_vehicles': '14',
#   'year': '2018'},
#  {'base_license_number': 'B02891',
#   'base_name': 'GLIDE LUXURY TRANSPORTATION, INC',
#   'month': '7',
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '21',
#   'unique_dispatched_vehicles': '4',
#   'year': '2016'},
#  {'base_license_number': 'B01233',
#   'base_name': 'NEW LACONIA RAD DISP INC',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '24433',
#   'unique_dispatched_vehicles': '80',
#   'year': '2016'},
#  {'base_license_number': 'B00652',
#   'base_name': 'RESCUE C/S INC',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2017',
#   'unique_dispatched_vehicles': '21',
#   'year': '2020'},
#  {'base_license_number': 'UBER',
#   'base_name': 'UBER',
#   'dba': 'UBER',
#   'month': '8',
#   'month_name': 'August',
#   'total_dispatched_shared_trips': '4027450',
#   'total_dispatched_trips': '14060879',
#   'unique_dispatched_vehicles': '72344',
#   'year': '2018'},
#  {'base_license_number': 'B01726',
#   'base_name': 'SUPER CLASS RADIO DISP INC',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '27',
#   'total_dispatched_trips': '7957',
#   'unique_dispatched_vehicles': '57',
#   'year': '2018'},
#  {'base_license_number': 'B00472',
#   'base_name': "FARRELL'S LEASING CO.",
#   'month': '8',
#   'month_name': 'August',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '470',
#   'unique_dispatched_vehicles': '39',
#   'year': '2019'},
#  {'base_license_number': 'B01721',
#   'base_name': 'W.K. CAR & LIMO SERVICE INC',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1574',
#   'unique_dispatched_vehicles': '20',
#   'year': '2020'},
#  {'base_license_number': 'B02517',
#   'base_name': 'LOS PAISANOS LUXURY C/S INC.',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '648',
#   'unique_dispatched_vehicles': '7',
#   'year': '2017'},
#  {'base_license_number': 'B03000',
#   'base_name': 'ZAPP CAR SERVICE INC.',
#   'month': '1',
#   'month_name': 'January',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '27',
#   'unique_dispatched_vehicles': '1',
#   'year': '2019'},
#  {'base_license_number': 'B02480',
#   'base_name': 'WOODHAVEN LIMOUSINE INC',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '834',
#   'unique_dispatched_vehicles': '29',
#   'year': '2016'},
#  {'base_license_number': 'B00171',
#   'base_name': 'CURB TRANSPORTATION SERVICES LLC.',
#   'month': '10',
#   'month_name': 'October',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '5002',
#   'unique_dispatched_vehicles': '26',
#   'year': '2015'},
#  {'base_license_number': 'B01727',
#   'base_name': 'CHAUFFEUR SERVICES, INC.',
#   'dba': 'NICE GUYS LIMO',
#   'month': '1',
#   'month_name': 'January',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '33',
#   'unique_dispatched_vehicles': '2',
#   'year': '2018'},
#  {'base_license_number': 'B00475',
#   'base_name': 'RIDGE TRANSPORTATION CORP.',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '3681',
#   'unique_dispatched_vehicles': '9',
#   'year': '2016'},
#  {'base_license_number': 'B02627',
#   'base_name': 'A PEGASUS LIMOUSINE CORP.',
#   'dba': 'APL LIMO',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '129',
#   'unique_dispatched_vehicles': '9',
#   'year': '2018'},
#  {'base_license_number': 'B02725',
#   'base_name': 'KIRIN TRANSPORTATION INC',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1274',
#   'unique_dispatched_vehicles': '23',
#   'year': '2017'},
#  {'base_license_number': 'B02566',
#   'base_name': 'GSL LIMOUSINES CORP.',
#   'month': '10',
#   'month_name': 'October',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1300',
#   'unique_dispatched_vehicles': '34',
#   'year': '2017'},
#  {'base_license_number': 'B01751',
#   'base_name': 'CONCORDE EXP OF N.Y. INC',
#   'month': '7',
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2901',
#   'unique_dispatched_vehicles': '10',
#   'year': '2017'},
#  {'base_license_number': 'B01742',
#   'base_name': 'AVALON TRANSPORTATION, LLC',
#   'month': '6',
#   'month_name': 'June',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '694',
#   'unique_dispatched_vehicles': '22',
#   'year': '2017'},
#  {'base_license_number': 'B02120',
#   'base_name': 'HARRISON GLOBAL LLC',
#   'dba': 'BOSTON COACH',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '5310',
#   'unique_dispatched_vehicles': '96',
#   'year': '2018'},
#  {'base_license_number': 'B02962',
#   'base_name': 'HEALTH BLACK CAR SERVICES, CORP',
#   'dba': 'ADON',
#   'month': '7',
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '506',
#   'unique_dispatched_vehicles': '6',
#   'year': '2019'},
#  {'base_license_number': 'B01973',
#   'base_name': 'RAJA CAR & LIMOUSINE SERVICE INC.',
#   'dba': 'ANGEL CAR SERVICE',
#   'month': '8',
#   'month_name': 'August',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1578',
#   'unique_dispatched_vehicles': '11',
#   'year': '2017'},
#  {'base_license_number': 'B02377',
#   'base_name': 'AMERICAN BASE #2. INC.',
#   'month': '8',
#   'month_name': 'August',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '398',
#   'unique_dispatched_vehicles': '6',
#   'year': '2016'},
#  {'base_license_number': 'B01362',
#   'base_name': 'AMERICAN BASE NO.1 INC.',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '33767',
#   'unique_dispatched_vehicles': '207',
#   'year': '2015'},
#  {'base_license_number': 'B00449',
#   'base_name': 'A KINGS HWY C/S INC.',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2981',
#   'unique_dispatched_vehicles': '10',
#   'year': '2019'},
#  {'base_license_number': 'B02306',
#   'base_name': 'ACCUELIMO LUXURY LLC',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '3437',
#   'unique_dispatched_vehicles': '26',
#   'year': '2015'},
#  {'base_license_number': 'B00445',
#   'base_name': 'JOE M LEASING CORP',
#   'dba': "FOUR TWO'S PVT C/S",
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '7614',
#   'unique_dispatched_vehicles': '21',
#   'year': '2019'},
#  {'base_license_number': 'B01088',
#   'base_name': 'PAISA 2 CAR  AND LIMOUSINE SERVICE INC',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '111',
#   'unique_dispatched_vehicles': '3',
#   'year': '2016'},
#  {'base_license_number': 'B02655',
#   'base_name': 'LONG ISLAND CITY CAR AND LIMO INC.',
#   'dba': 'A2B CORPORATE SEDAN',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '735',
#   'unique_dispatched_vehicles': '9',
#   'year': '2019'},
#  {'base_license_number': 'B02315',
#   'base_name': 'LA MORENITA CAR LIMO SERVICE INC',
#   'month': '1',
#   'month_name': 'January',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '5946',
#   'unique_dispatched_vehicles': '35',
#   'year': '2017'},
#  {'base_license_number': 'B00492',
#   'base_name': 'BLU-WHITE ASSOCIATED TRANSPORTATION SERVICE INC',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '4959',
#   'unique_dispatched_vehicles': '24',
#   'year': '2017'},
#  {'base_license_number': 'B01730',
#   'base_name': 'LUCKY EXPRESS CORPORATION',
#   'dba': 'GOOD LUCK CAR SVCE',
#   'month': '9',
#   'month_name': 'September',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '14898',
#   'unique_dispatched_vehicles': '128',
#   'year': '2015'},
#  {'base_license_number': 'B01318',
#   'base_name': 'LOWER EAST SIDE C/S CORP',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '15330',
#   'unique_dispatched_vehicles': '67',
#   'year': '2016'},
#  {'base_license_number': 'B00449',
#   'base_name': 'A KINGS HWY C/S INC.',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2555',
#   'unique_dispatched_vehicles': '11',
#   'year': '2019'},
#  {'base_license_number': 'B02315',
#   'base_name': 'LA MORENITA CAR LIMO SERVICE INC',
#   'month': '6',
#   'month_name': 'June',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '4546',
#   'unique_dispatched_vehicles': '21',
#   'year': '2017'},
#  {'base_license_number': 'B01340',
#   'base_name': 'UNICAR COMPANY INC',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '21332',
#   'unique_dispatched_vehicles': '106',
#   'year': '2016'},
#  {'base_license_number': 'B02021',
#   'base_name': 'EASYRIDE CAR SERVICE INC.',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '992',
#   'unique_dispatched_vehicles': '3',
#   'year': '2017'},
#  {'base_license_number': 'B03022',
#   'base_name': 'BLACK CAR EXPRESS.COM CORP',
#   'month': '1',
#   'month_name': 'January',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '137',
#   'unique_dispatched_vehicles': '3',
#   'year': '2020'},
#  {'base_license_number': 'B01332',
#   'base_name': 'SKYWAY CAR SERVICE EXPRESS INC.',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '939',
#   'unique_dispatched_vehicles': '19',
#   'year': '2017'},
#  {'base_license_number': 'B01069',
#   'base_name': 'RPO CAR AND LIMOUSINE SERVICE INC.',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2320',
#   'unique_dispatched_vehicles': '14',
#   'year': '2019'},
#  {'base_license_number': 'B02925',
#   'base_name': 'SIGNATURE BLACK CAR LLC',
#   'month': '8',
#   'month_name': 'August',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '4',
#   'unique_dispatched_vehicles': '3',
#   'year': '2016'},
#  {'base_license_number': 'B01413',
#   'base_name': 'SFL INC',
#   'month': '9',
#   'month_name': 'September',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1193',
#   'unique_dispatched_vehicles': '43',
#   'year': '2015'},
#  {'base_license_number': 'B02252',
#   'base_name': 'ASIANA LIMOUSINE INC.',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '16',
#   'unique_dispatched_vehicles': '4',
#   'year': '2018'},
#  {'base_license_number': 'B02833',
#   'base_name': 'ADVANCED LUXURY LIMO SVC. INC.',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '3505',
#   'unique_dispatched_vehicles': '19',
#   'year': '2017'},
#  {'base_license_number': 'B01553',
#   'base_name': 'CITY LINE CAR SERVICE INC',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '23285',
#   'unique_dispatched_vehicles': '115',
#   'year': '2016'},
#  {'base_license_number': 'B01663',
#   'base_name': 'CIBAO RADIO DISPATCH',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '3382',
#   'unique_dispatched_vehicles': '24',
#   'year': '2020'},
#  {'base_license_number': 'B02470',
#   'base_name': 'VAHANA INC.',
#   'month': '10',
#   'month_name': 'October',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '624',
#   'unique_dispatched_vehicles': '12',
#   'year': '2015'},
#  {'base_license_number': 'B01118',
#   'base_name': 'INTERNATIONAL CAR SERVICE INC.',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '578',
#   'unique_dispatched_vehicles': '6',
#   'year': '2019'},
#  {'base_license_number': 'B00375',
#   'base_name': 'THE EXCELLENT C/S INC',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '20642',
#   'unique_dispatched_vehicles': '86',
#   'year': '2016'},
#  {'base_license_number': 'B03110',
#   'base_name': 'BETTER CAR & LIMOUSINE SERVICE INC',
#   'dba': 'BELTWAY CAR SERVICE',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1',
#   'unique_dispatched_vehicles': '1',
#   'year': '2016'},
#  {'base_license_number': 'B02874',
#   'base_name': 'CAPSTAR CHAUFFEURS,INC.',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '130',
#   'unique_dispatched_vehicles': '9',
#   'year': '2016'},
#  {'base_license_number': 'B01751',
#   'base_name': 'CONCORDE EXP OF N.Y. INC',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '3440',
#   'unique_dispatched_vehicles': '11',
#   'year': '2017'},
#  {'base_license_number': 'B01300',
#   'base_name': 'KENNEDY RAD DISP INC',
#   'month': '10',
#   'month_name': 'October',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '9076',
#   'unique_dispatched_vehicles': '78',
#   'year': '2017'},
#  {'base_license_number': 'B01066',
#   'base_name': 'DOMINICANA RAD DISP INC',
#   'month': '7',
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '5733',
#   'unique_dispatched_vehicles': '41',
#   'year': '2019'},
#  {'base_license_number': 'B00955',
#   'base_name': 'GOLDEN-TOWN CAR & LIMOUSINE SERVICE INC.',
#   'month': '8',
#   'month_name': 'August',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '700',
#   'unique_dispatched_vehicles': '26',
#   'year': '2018'},
#  {'base_license_number': 'B01236',
#   'base_name': 'BLS LIMO SVC OF NY INC',
#   'month': '1',
#   'month_name': 'January',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2660',
#   'unique_dispatched_vehicles': '110',
#   'year': '2020'},
#  {'base_license_number': 'B02133',
#   'base_name': 'TWR CAR & LIMO, INC.',
#   'month': '6',
#   'month_name': 'June',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '6235',
#   'unique_dispatched_vehicles': '68',
#   'year': '2017'},
#  {'base_license_number': 'B01066',
#   'base_name': 'DOMINICANA RAD DISP INC',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '8699',
#   'unique_dispatched_vehicles': '54',
#   'year': '2018'},
#  {'base_license_number': 'B00401',
#   'base_name': 'TREMONT DISPATCHING CORP',
#   'month': '6',
#   'month_name': 'June',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '161',
#   'unique_dispatched_vehicles': '3',
#   'year': '2016'},
#  {'base_license_number': 'B00965',
#   'base_name': 'BEN JEVO MGT. INC.',
#   'dba': 'NEWPORT CAR SERVICE',
#   'month': '8',
#   'month_name': 'August',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '8713',
#   'unique_dispatched_vehicles': '58',
#   'year': '2018'},
#  {'base_license_number': 'B01529',
#   'base_name': 'J.I.G. TRANSPORT CORP.',
#   'dba': 'ECKFORD CAR SERVICE',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1674',
#   'unique_dispatched_vehicles': '11',
#   'year': '2018'},
#  {'base_license_number': 'VIA',
#   'base_name': 'VIA',
#   'dba': 'VIA',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '255655',
#   'unique_dispatched_vehicles': '923',
#   'year': '2015'},
#  {'base_license_number': 'B02248',
#   'base_name': 'HYBRID LIMO EXPRESS INC.',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1557',
#   'unique_dispatched_vehicles': '8',
#   'year': '2018'},
#  {'base_license_number': 'B01821',
#   'base_name': 'EMPIRE TRANSPORTATION SERVICE INC.',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1363',
#   'unique_dispatched_vehicles': '9',
#   'year': '2018'},
#  {'base_license_number': 'B02229',
#   'base_name': 'NEW FAT INC.',
#   'dba': 'ELEGANTE',
#   'month': '6',
#   'month_name': 'June',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '6856',
#   'unique_dispatched_vehicles': '69',
#   'year': '2017'},
#  {'base_license_number': 'UBER',
#   'base_name': 'UBER',
#   'dba': 'UBER',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2259575',
#   'unique_dispatched_vehicles': '14290',
#   'year': '2015'},
#  {'base_license_number': 'B00221',
#   'base_name': 'PROFESSIONAL CAR SERVICE INC',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '7849',
#   'unique_dispatched_vehicles': '54',
#   'year': '2018'},
#  {'base_license_number': 'B01777',
#   'base_name': 'PREMIUM RADIO DISP & MULTI SVC',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '19934',
#   'unique_dispatched_vehicles': '182',
#   'year': '2016'},
#  {'base_license_number': 'B00906',
#   'base_name': 'OLYMPIA OPERATING CAR SERVICE OF NY CORP.',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1004',
#   'unique_dispatched_vehicles': '6',
#   'year': '2017'},
#  {'base_license_number': 'B02060',
#   'base_name': 'AMERICAN LIMOUSINE LLC',
#   'dba': 'FLYTE TYME WORLDWIDE/ADDISON LEE/TRISTAR',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '4197',
#   'unique_dispatched_vehicles': '119',
#   'year': '2018'},
#  {'base_license_number': 'B02793',
#   'base_name': 'SEAVIEW ISLAND CAR SERVICE',
#   'month': '10',
#   'month_name': 'October',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '93',
#   'unique_dispatched_vehicles': '1',
#   'year': '2018'},
#  {'base_license_number': 'B02627',
#   'base_name': 'A PEGASUS LIMOUSINE CORP.',
#   'dba': 'APL LIMO',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '276',
#   'unique_dispatched_vehicles': '10',
#   'year': '2017'},
#  {'base_license_number': 'B02912',
#   'base_name': 'FIRST CLASS LUXURY INC',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1633',
#   'unique_dispatched_vehicles': '9',
#   'year': '2017'},
#  {'base_license_number': 'B00369',
#   'base_name': 'BOULEVARD OPERATING INC.',
#   'month': '9',
#   'month_name': 'September',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '456',
#   'unique_dispatched_vehicles': '9',
#   'year': '2018'},
#  {'base_license_number': 'B02460',
#   'base_name': 'CABOT LIMO NY CORP.',
#   'month': '8',
#   'month_name': 'August',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '949',
#   'unique_dispatched_vehicles': '25',
#   'year': '2016'},
#  {'base_license_number': 'B00021',
#   'base_name': 'MEXICANA HIGH CLASS INC.',
#   'dba': 'CAPITAL CAR SERVICE',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1309',
#   'unique_dispatched_vehicles': '28',
#   'year': '2020'},
#  {'base_license_number': 'B01128',
#   'base_name': 'PAK-EAGLE INC.',
#   'dba': 'JEWEL CAR SERVICE',
#   'month': '8',
#   'month_name': 'August',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '4108',
#   'unique_dispatched_vehicles': '15',
#   'year': '2016'},
#  {'base_license_number': 'B01391',
#   'base_name': "ROSE 'N' DALE C/S INC",
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '430',
#   'unique_dispatched_vehicles': '6',
#   'year': '2020'},
#  {'base_license_number': 'B02901',
#   'base_name': 'GALLANT LUXURY SERVICE CORP.',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '864',
#   'unique_dispatched_vehicles': '16',
#   'year': '2017'},
#  {'base_license_number': 'B00991',
#   'base_name': 'BLUE LANE CAR SERVICE INC',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '289',
#   'unique_dispatched_vehicles': '12',
#   'year': '2018'},
#  {'base_license_number': 'B01341',
#   'base_name': 'A NEW DAY RAD DISP INC',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '3527',
#   'unique_dispatched_vehicles': '26',
#   'year': '2018'},
#  {'base_license_number': 'LYFT',
#   'base_name': 'LYFT',
#   'dba': 'LYFT',
#   'month': '6',
#   'month_name': 'June',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1073973',
#   'unique_dispatched_vehicles': '15095',
#   'year': '2016'},
#  {'base_license_number': 'B00160',
#   'base_name': 'JAFFA CAR & LIMO SVC INC',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '3941',
#   'unique_dispatched_vehicles': '21',
#   'year': '2016'},
#  {'base_license_number': 'B02855',
#   'base_name': 'JUNIORS LUXURY INC',
#   'dba': 'MEGA JUNIORS',
#   'month': '10',
#   'month_name': 'October',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2147',
#   'unique_dispatched_vehicles': '23',
#   'year': '2019'},
#  {'base_license_number': 'B02838',
#   'base_name': 'THA MAYA CAR SERVICE INC',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '557',
#   'unique_dispatched_vehicles': '12',
#   'year': '2016'},
#  {'base_license_number': 'B01124',
#   'base_name': 'COOPERATIVA CLBNA DE CON INC',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '4083',
#   'unique_dispatched_vehicles': '32',
#   'year': '2017'},
#  {'base_license_number': 'B02447',
#   'base_name': 'LUIGI MEMO INC.',
#   'dba': 'VIEW',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '49',
#   'unique_dispatched_vehicles': '14',
#   'year': '2019'},
#  {'base_license_number': 'B02196',
#   'base_name': 'N & T DOUBLE DIAMOND LIMOUSINES, INC.',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '29',
#   'unique_dispatched_vehicles': '4',
#   'year': '2017'},
#  {'base_license_number': 'B02111',
#   'base_name': 'HUANG HOU CAR SERVICES INC.',
#   'dba': 'HUANG HOU CAR SERVICES INC.',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '23277',
#   'unique_dispatched_vehicles': '106',
#   'year': '2018'},
#  {'base_license_number': 'B01768',
#   'base_name': 'NEW SUPERIOR RADIO GRP CORP',
#   'month': '7',
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '12215',
#   'unique_dispatched_vehicles': '80',
#   'year': '2019'},
#  {'base_license_number': 'B02127',
#   'base_name': 'CONTINENTAL RIDE, INC.',
#   'dba': 'I + I TRANSPORTATION',
#   'month': '9',
#   'month_name': 'September',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '130',
#   'unique_dispatched_vehicles': '7',
#   'year': '2015'},
#  {'base_license_number': 'B01273',
#   'base_name': 'PUERTO RICO CAR SERVICE INC.',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1602',
#   'unique_dispatched_vehicles': '7',
#   'year': '2019'},
#  {'base_license_number': 'B02770',
#   'base_name': 'CAVALIER CAR & LIMOUSINE, INC.',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '661',
#   'unique_dispatched_vehicles': '12',
#   'year': '2016'},
#  {'base_license_number': 'B00448',
#   'base_name': 'DIAL CAR INC.',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '254',
#   'unique_dispatched_vehicles': '42',
#   'year': '2017'},
#  {'base_license_number': 'B00789',
#   'base_name': 'VITAL TRANSPORTATION INC.',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1877',
#   'unique_dispatched_vehicles': '167',
#   'year': '2019'},
#  {'base_license_number': 'B02345',
#   'base_name': 'WESTCHESTER ACQUISITION CORP.',
#   'month': '8',
#   'month_name': 'August',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2709',
#   'unique_dispatched_vehicles': '79',
#   'year': '2016'},
#  {'base_license_number': 'B02408',
#   'base_name': 'PETER EXECUTIVE LIMOUSINE, CORP',
#   'month': '7',
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '92',
#   'unique_dispatched_vehicles': '9',
#   'year': '2016'},
#  {'base_license_number': 'B02643',
#   'base_name': 'LORY CAR SERVICE CORP.',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1241',
#   'unique_dispatched_vehicles': '16',
#   'year': '2019'},
#  {'base_license_number': 'B02563',
#   'base_name': 'FENIX XL CAR AND LIMO SERVICE CORP.',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '18003',
#   'unique_dispatched_vehicles': '67',
#   'year': '2016'},
#  {'base_license_number': 'VIA',
#   'base_name': 'VIA',
#   'dba': 'VIA',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '429572',
#   'unique_dispatched_vehicles': '1318',
#   'year': '2016'},
#  {'base_license_number': 'B02133',
#   'base_name': 'TWR CAR & LIMO, INC.',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '6885',
#   'unique_dispatched_vehicles': '85',
#   'year': '2016'},
#  {'base_license_number': 'B02184',
#   'base_name': 'DMCLS, INC.',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '210',
#   'unique_dispatched_vehicles': '7',
#   'year': '2017'},
#  {'base_license_number': 'B02892',
#   'base_name': 'SEAMAN EXPRESS CORP.',
#   'month': '8',
#   'month_name': 'August',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '34',
#   'unique_dispatched_vehicles': '11',
#   'year': '2018'},
#  {'base_license_number': 'B01341',
#   'base_name': 'A NEW DAY RAD DISP INC',
#   'month': '10',
#   'month_name': 'October',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '4410',
#   'unique_dispatched_vehicles': '31',
#   'year': '2017'},
#  {'base_license_number': 'B01990',
#   'base_name': 'SUK INCORPORATED',
#   'dba': 'RAINBOW LIMO',
#   'month': '8',
#   'month_name': 'August',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '700',
#   'unique_dispatched_vehicles': '43',
#   'year': '2016'},
#  {'base_license_number': 'B01727',
#   'base_name': 'CHAUFFEUR SERVICES, INC.',
#   'dba': 'NICE GUYS LIMO',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '153',
#   'unique_dispatched_vehicles': '6',
#   'year': '2015'},
#  {'base_license_number': 'B00608',
#   'base_name': 'SUMMIT CORPORATE CAR INC.',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1855',
#   'unique_dispatched_vehicles': '39',
#   'year': '2018'},
#  {'base_license_number': 'B02823',
#   'base_name': 'AAA FAMILY LIMOUSINE SERVICE INC',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '30',
#   'unique_dispatched_vehicles': '3',
#   'year': '2019'},
#  {'base_license_number': 'B02839',
#   'base_name': 'YERUSHALAYIM CAR&LIMO INC',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '101',
#   'unique_dispatched_vehicles': '2',
#   'year': '2017'},
#  {'base_license_number': 'B02521',
#   'base_name': 'PICTURE PROPERTIES, INC.',
#   'dba': 'DEUCES TRANSPORT SERVICES',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '5995',
#   'unique_dispatched_vehicles': '17',
#   'year': '2018'},
#  {'base_license_number': 'B02120',
#   'base_name': 'HARRISON GLOBAL LLC',
#   'dba': 'BOSTON COACH',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '8288',
#   'unique_dispatched_vehicles': '164',
#   'year': '2016'},
#  {'base_license_number': 'b01048',
#   'base_name': 'HILLSIDE 24 HOURS RADIO DISPATCH INC',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1987',
#   'unique_dispatched_vehicles': '8',
#   'year': '2016'},
#  {'base_license_number': 'B02360',
#   'base_name': 'BRIDGES LIMOUSINE INC',
#   'dba': 'EXCELLENT LIMOUSINE',
#   'month': '8',
#   'month_name': 'August',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '69',
#   'unique_dispatched_vehicles': '4',
#   'year': '2019'},
#  {'base_license_number': 'B02463',
#   'base_name': 'MORENITA EXPRESS CAR SERVICE INC.',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1111',
#   'unique_dispatched_vehicles': '9',
#   'year': '2016'},
#  {'base_license_number': 'B01995',
#   'base_name': "NYMEX UNO EXECUTIVE SEDAN'S INC",
#   'dba': 'NYMEX CAR SERVICE',
#   'month': '1',
#   'month_name': 'January',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2139',
#   'unique_dispatched_vehicles': '15',
#   'year': '2017'},
#  {'base_license_number': 'B01336',
#   'base_name': 'BAY EXPRESS CORP.',
#   'month': '6',
#   'month_name': 'June',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2374',
#   'unique_dispatched_vehicles': '18',
#   'year': '2019'},
#  {'base_license_number': 'B02219',
#   'base_name': 'ALL QUEENS CAR & LIMOUSINE INC.',
#   'dba': 'CAR ON TIME',
#   'month': '8',
#   'month_name': 'August',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '210',
#   'unique_dispatched_vehicles': '11',
#   'year': '2015'},
#  {'base_license_number': 'B01467',
#   'base_name': 'NEW EXPERIENCE #1 INC',
#   'month': '6',
#   'month_name': 'June',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '16679',
#   'unique_dispatched_vehicles': '77',
#   'year': '2016'},
#  {'base_license_number': 'B01109',
#   'base_name': 'UNITED EXP C/L SVCE',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '4749',
#   'unique_dispatched_vehicles': '24',
#   'year': '2018'},
#  {'base_license_number': 'B02739',
#   'base_name': 'TRAXLINE CAR SERVICE INC.',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '828',
#   'unique_dispatched_vehicles': '10',
#   'year': '2017'},
#  {'base_license_number': 'B02196',
#   'base_name': 'N & T DOUBLE DIAMOND LIMOUSINES, INC.',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '14',
#   'unique_dispatched_vehicles': '2',
#   'year': '2019'},
#  {'base_license_number': 'B02838',
#   'base_name': 'THA MAYA CAR SERVICE INC',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '436',
#   'unique_dispatched_vehicles': '8',
#   'year': '2015'},
#  {'base_license_number': 'B02868',
#   'base_name': 'CHA CHA TRANSPORTATION CORP',
#   'month': '9',
#   'month_name': 'September',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '825',
#   'unique_dispatched_vehicles': '7',
#   'year': '2018'},
#  {'base_license_number': 'B01061',
#   'base_name': 'DAT RADIO DISP INC',
#   'month': '8',
#   'month_name': 'August',
# ...
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '4373',
#   'unique_dispatched_vehicles': '12',
#   'year': '2018'},
#  {'base_license_number': 'B02641',
#   'base_name': 'AVENUE X CAR SERVICE INC.',
#   'dba': 'PRESTIGE CAR SERVICE',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1876',
#   'unique_dispatched_vehicles': '11',
#   'year': '2020'},
#  {'base_license_number': 'B02067',
#   'base_name': 'GROUP AMERICAR TRANSPORTATION,LLC.',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2720',
#   'unique_dispatched_vehicles': '76',
#   'year': '2018'},
#  {'base_license_number': 'B02145',
#   'base_name': 'NEW 2020 CAR SERVICE INC',
#   'month': '10',
#   'month_name': 'October',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '770',
#   'unique_dispatched_vehicles': '6',
#   'year': '2017'},
#  {'base_license_number': 'B02447',
#   'base_name': 'LUIGI MEMO INC.',
#   'dba': 'VIEW',
#   'month': '7',
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '19',
#   'unique_dispatched_vehicles': '10',
#   'year': '2016'},
#  {'base_license_number': 'B02762',
#   'base_name': 'SHOWTIME TRANSPORTATION CORP.',
#   'month': '10',
#   'month_name': 'October',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1716',
#   'unique_dispatched_vehicles': '20',
#   'year': '2018'},
#  {'base_license_number': 'b00984',
#   'base_name': 'P J CAR SVCE',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2855',
#   'unique_dispatched_vehicles': '9',
#   'year': '2016'},
#  {'base_license_number': 'B02657',
#   'base_name': 'MALCOLM LIMO EXPRESS CORP.',
#   'month': '8',
#   'month_name': 'August',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '5555',
#   'unique_dispatched_vehicles': '46',
#   'year': '2019'},
#  {'base_license_number': 'B02563',
#   'base_name': 'FENIX XL CAR AND LIMO SERVICE CORP.',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '222',
#   'unique_dispatched_vehicles': '40',
#   'year': '2017'},
#  {'base_license_number': 'B00337',
#   'base_name': 'KEW GARDENS ENTERPRISES INC.',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '130',
#   'unique_dispatched_vehicles': '3',
#   'year': '2020'},
#  {'base_license_number': 'B02162',
#   'base_name': 'A B C SHUTTLE SERVICES CORPORATION',
#   'dba': 'ABC CAR SERVICES',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '328',
#   'unique_dispatched_vehicles': '14',
#   'year': '2019'},
#  {'base_license_number': 'B02095',
#   'base_name': 'COMMONWEALTH WORLDWIDE CHAUFFEURED TRANSP. OF NY,',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1902',
#   'unique_dispatched_vehicles': '100',
#   'year': '2016'},
#  {'base_license_number': 'B02501',
#   'base_name': 'EAST HANOVER AUTO SALES, INC.',
#   'dba': 'MY LIMOUSINE SERVICE',
#   'month': '10',
#   'month_name': 'October',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '59',
#   'unique_dispatched_vehicles': '9',
#   'year': '2015'},
#  {'base_license_number': 'B01312',
#   'base_name': 'BROOKLYN RAD DISP INC',
#   'month': '9',
#   'month_name': 'September',
#   'total_dispatched_shared_trips': '87',
#   'total_dispatched_trips': '3742',
#   'unique_dispatched_vehicles': '26',
#   'year': '2018'},
#  {'base_license_number': 'B01498',
#   'base_name': 'MEGA CAR SVCE CORP',
#   'month': '6',
#   'month_name': 'June',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '9533',
#   'unique_dispatched_vehicles': '39',
#   'year': '2016'},
#  {'base_license_number': 'B00446',
#   'base_name': 'COMMUNICAR INCORPORATED',
#   'month': '1',
#   'month_name': 'January',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '6006',
#   'unique_dispatched_vehicles': '132',
#   'year': '2016'},
#  {'base_license_number': 'B01339',
#   'base_name': 'R C AUDUBON SVC INC',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '16225',
#   'unique_dispatched_vehicles': '147',
#   'year': '2015'},
#  {'base_license_number': 'B01200',
#   'base_name': 'NEW YORK APPLE CAR SERVICE INC',
#   'dba': 'N Y LIMO & CAR SVCE',
#   'month': '6',
#   'month_name': 'June',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '5555',
#   'unique_dispatched_vehicles': '27',
#   'year': '2016'},
#  {'base_license_number': 'B03080',
#   'base_name': 'AMBAR TRANSPORTATION INC.',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '4351',
#   'unique_dispatched_vehicles': '59',
#   'year': '2019'},
#  {'base_license_number': 'B00987',
#   'base_name': 'MARLBORO CAR SERVICE INC.',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2337',
#   'unique_dispatched_vehicles': '19',
#   'year': '2019'},
#  {'base_license_number': 'B02552',
#   'base_name': 'INTERSTATE LUXURY LIMOUSINES INC.',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2426',
#   'unique_dispatched_vehicles': '13',
#   'year': '2018'},
#  {'base_license_number': 'B00457',
#   'base_name': 'PREMIUM BRONX CORP',
#   'month': '7',
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '223',
#   'unique_dispatched_vehicles': '53',
#   'year': '2018'},
#  {'base_license_number': 'B01406',
#   'base_name': 'GOTHAM CAR SERVICE INC.',
#   'dba': 'LEGEND CAR SERVICE',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '426',
#   'unique_dispatched_vehicles': '12',
#   'year': '2020'},
#  {'base_license_number': 'B02217',
#   'base_name': 'PCS LIMOUSINE INC.',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '784',
#   'unique_dispatched_vehicles': '14',
#   'year': '2015'},
#  {'base_license_number': 'B01328',
#   'base_name': 'DV LUXURY CAR SERVICE INC',
#   'dba': 'RIDE SAFE CAR SERVICE',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1115',
#   'unique_dispatched_vehicles': '23',
#   'year': '2018'},
#  {'base_license_number': 'B02491',
#   'base_name': 'CALL THREES LLC',
#   'month': '7',
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '879',
#   'unique_dispatched_vehicles': '6',
#   'year': '2015'},
#  {'base_license_number': 'B03243',
#   'base_name': 'CAPRICE CAR SERVICE NO.2,INC',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2048',
#   'unique_dispatched_vehicles': '15',
#   'year': '2020'},
#  {'base_license_number': 'B00210',
#   'base_name': 'HOWARD CAR SERVICE,INC.',
#   'month': '9',
#   'month_name': 'September',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '133',
#   'unique_dispatched_vehicles': '13',
#   'year': '2019'},
#  {'base_license_number': 'B01088',
#   'base_name': 'PAISA 2 CAR  AND LIMOUSINE SERVICE INC',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '264',
#   'unique_dispatched_vehicles': '6',
#   'year': '2016'},
#  {'base_license_number': 'B02435',
#   'base_name': 'TEINETCO, INC',
#   'month': '1',
#   'month_name': 'January',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '152',
#   'unique_dispatched_vehicles': '19',
#   'year': '2016'},
#  {'base_license_number': 'B01145',
#   'base_name': 'ULTRA RADIO DISP INC',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '47039',
#   'unique_dispatched_vehicles': '272',
#   'year': '2017'},
#  {'base_license_number': 'B00911',
#   'base_name': 'RIVERSIDE PLUS RADIO DISPATCH, INC.',
#   'dba': 'NEW WEBSTER CAR & LIMO SERVICE',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '14175',
#   'unique_dispatched_vehicles': '90',
#   'year': '2016'},
#  {'base_license_number': 'B01768',
#   'base_name': 'NEW SUPERIOR RADIO GRP CORP',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '4041',
#   'unique_dispatched_vehicles': '32',
#   'year': '2018'},
#  {'base_license_number': 'B01721',
#   'base_name': 'W.K. CAR & LIMO SERVICE INC',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '6623',
#   'unique_dispatched_vehicles': '43',
#   'year': '2016'},
#  {'base_license_number': 'B02163',
#   'base_name': 'JUNIORS EXPRESS CAR SERVICE INC.',
#   'month': '7',
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1529',
#   'unique_dispatched_vehicles': '13',
#   'year': '2019'},
#  {'base_license_number': 'B01751',
#   'base_name': 'CONCORDE EXP OF N.Y. INC',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '3159',
#   'unique_dispatched_vehicles': '11',
#   'year': '2019'},
#  {'base_license_number': 'B00227',
#   'base_name': 'PARK WEST EXEC. SERVICES, INC.',
#   'dba': 'TOWN CARS',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '627',
#   'unique_dispatched_vehicles': '20',
#   'year': '2020'},
#  {'base_license_number': 'B03152',
#   'base_name': 'EXIT LUXURY INC.',
#   'month': '6',
#   'month_name': 'June',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2',
#   'unique_dispatched_vehicles': '1',
#   'year': '2019'},
#  {'base_license_number': 'B03084',
#   'base_name': 'PERSIST CORPORATION',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1431',
#   'unique_dispatched_vehicles': '17',
#   'year': '2019'},
#  {'base_license_number': 'B03030',
#   'base_name': 'Q-FIRST LIMOUSINE CORP.',
#   'month': '8',
#   'month_name': 'August',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '123',
#   'unique_dispatched_vehicles': '9',
#   'year': '2019'},
#  {'base_license_number': 'B00652',
#   'base_name': 'RESCUE C/S INC',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '6216',
#   'unique_dispatched_vehicles': '19',
#   'year': '2016'},
#  {'base_license_number': 'B02942',
#   'base_name': 'FANNY RADIO DISPATCHER SERVICE INC.',
#   'month': '10',
#   'month_name': 'October',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '865',
#   'unique_dispatched_vehicles': '7',
#   'year': '2017'},
#  {'base_license_number': 'B02996',
#   'base_name': 'FOREVER BLUE CAR SERVICE INC.',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1643',
#   'unique_dispatched_vehicles': '25',
#   'year': '2019'},
#  {'base_license_number': 'B02797',
#   'base_name': 'CJ LIMOUSINE LLC',
#   'month': '10',
#   'month_name': 'October',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '433',
#   'unique_dispatched_vehicles': '9',
#   'year': '2017'},
#  {'base_license_number': 'B01328',
#   'base_name': 'DV LUXURY CAR SERVICE INC',
#   'dba': 'RIDE SAFE CAR SERVICE',
#   'month': '10',
#   'month_name': 'October',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '4215',
#   'unique_dispatched_vehicles': '72',
#   'year': '2018'},
#  {'base_license_number': 'B02657',
#   'base_name': 'MALCOLM LIMO EXPRESS CORP.',
#   'month': '12',
#   'month_name': 'December',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2952',
#   'unique_dispatched_vehicles': '18',
#   'year': '2016'},
#  {'base_license_number': 'B01109',
#   'base_name': 'UNITED EXP C/L SVCE',
#   'month': '2',
#   'month_name': 'February',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '8020',
#   'unique_dispatched_vehicles': '43',
#   'year': '2017'},
#  {'base_license_number': 'B00256',
#   'base_name': 'FAST OPERATING CORP',
#   'dba': 'CARMEL C/L SVCE',
#   'month': '10',
#   'month_name': 'October',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '62748',
#   'unique_dispatched_vehicles': '736',
#   'year': '2016'},
#  {'base_license_number': 'B02834',
#   'base_name': '811 TRANSIT CORP',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2491',
#   'unique_dispatched_vehicles': '9',
#   'year': '2020'},
#  {'base_license_number': 'B02590',
#   'base_name': 'LUXOR LIMO INC',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2233',
#   'unique_dispatched_vehicles': '48',
#   'year': '2017'},
#  {'base_license_number': 'B02975',
#   'base_name': 'LI YANG LIMOUSINE INC',
#   'month': '3',
#   'month_name': 'March',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '41',
#   'unique_dispatched_vehicles': '20',
#   'year': '2019'},
#  {'base_license_number': 'B02505',
#   'base_name': 'TRELAWNY CAR SERVICE INC',
#   'month': '6',
#   'month_name': 'June',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1218',
#   'unique_dispatched_vehicles': '9',
#   'year': '2019'},
#  {'base_license_number': 'B00039',
#   'base_name': 'BERMUDA LIMOUSINE SERVICE INC.',
#   'month': '10',
#   'month_name': 'October',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '1158',
#   'unique_dispatched_vehicles': '45',
#   'year': '2017'},
#  {'base_license_number': 'B00235',
#   'base_name': 'ARISTACAR & LIMOUSINE, LTD.',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '540',
#   'unique_dispatched_vehicles': '19',
#   'year': '2019'},
#  {'base_license_number': 'LYFT',
#   'base_name': 'LYFT',
#   'dba': 'LYFT',
#   'month': '11',
#   'month_name': 'November',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '450483',
#   'unique_dispatched_vehicles': '7023',
#   'year': '2015'},
#  {'base_license_number': 'B02917',
#   'base_name': 'C & A BLACK CAR CORP.',
#   'month': '7',
#   'month_name': 'July',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '170',
#   'unique_dispatched_vehicles': '25',
#   'year': '2017'},
#  {'base_license_number': 'B01980',
#   'base_name': 'READY TO ROLL TRANSPORTATION, INC.',
#   'month': '1',
#   'month_name': 'January',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '681',
#   'unique_dispatched_vehicles': '20',
#   'year': '2016'},
#  {'base_license_number': 'B01653',
#   'base_name': "ART'S PLACE INC.",
#   'dba': 'ON TIME CAR SERVICE',
#   'month': '10',
#   'month_name': 'October',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2219',
#   'unique_dispatched_vehicles': '17',
#   'year': '2017'},
#  {'base_license_number': 'B01273',
#   'base_name': 'PUERTO RICO CAR SERVICE INC.',
#   'month': '5',
#   'month_name': 'May',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '10092',
#   'unique_dispatched_vehicles': '53',
#   'year': '2017'},
#  {'base_license_number': 'B00900',
#   'base_name': 'BIG Q CAR SVC. INC.',
#   'month': '10',
#   'month_name': 'October',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '52623',
#   'unique_dispatched_vehicles': '198',
#   'year': '2016'},
#  {'base_license_number': 'B01146',
#   'base_name': 'CHURCH AVE C/S INC',
#   'month': '4',
#   'month_name': 'April',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '8494',
#   'unique_dispatched_vehicles': '35',
#   'year': '2019'},
#  {'base_license_number': 'B02067',
#   'base_name': 'GROUP AMERICAR TRANSPORTATION,LLC.',
#   'month': '10',
#   'month_name': 'October',
#   'total_dispatched_shared_trips': '0',
#   'total_dispatched_trips': '2243',
#   'unique_dispatched_vehicles': '62',
#   'year': '2019'}]

# %%
print(json.dumps(uber_data, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "base_license_number": "B00053",
#         "base_name": "CHARGE AND RIDE INC",
#         "month": "6",
#         "month_name": "June",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "681",
#         "unique_dispatched_vehicles": "34",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B02699",
#         "base_name": "PRESIDENTIAL LUXURY LIMO INC.",
#         "month": "7",
#         "month_name": "July",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1170",
#         "unique_dispatched_vehicles": "32",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B01176",
#         "base_name": "SANTO DOMINGO CAR LIMO SERVICES INC",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "19429",
#         "unique_dispatched_vehicles": "88",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B00837",
#         "base_name": "CAREY LIMO N Y INC",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "4673",
#         "unique_dispatched_vehicles": "146",
#         "year": "2020"
#     },
#     {
#         "base_license_number": "B02191",
#         "base_name": "US LIMO SYSTEM INC",
#         "month": "7",
#         "month_name": "July",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "769",
#         "unique_dispatched_vehicles": "27",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B01970",
#         "base_name": "GRAFE STREET SERVICE CORP.",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "482",
#         "unique_dispatched_vehicles": "10",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B02641",
#         "base_name": "AVENUE X CAR SERVICE INC.",
#         "dba": "PRESTIGE CAR SERVICE",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2465",
#         "unique_dispatched_vehicles": "15",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B00225",
#         "base_name": "DELANCEY TRANSPORTATION INC.",
#         "month": "9",
#         "month_name": "September",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "22759",
#         "unique_dispatched_vehicles": "123",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B01381",
#         "base_name": "CLASSIC CAR SERVICE CORP.",
#         "dba": "PAISA CLASSIC",
#         "month": "1",
#         "month_name": "January",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1631",
#         "unique_dispatched_vehicles": "17",
#         "year": "2020"
#     },
#     {
#         "base_license_number": "B02965",
#         "base_name": "ORION LUXURY CORP",
#         "month": "1",
#         "month_name": "January",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "723",
#         "unique_dispatched_vehicles": "13",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B01039",
#         "base_name": "NYC WHEELS CAR SERVICE INC.",
#         "dba": "COMMUNICARE CAR SERVICE",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "6064",
#         "unique_dispatched_vehicles": "22",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B01362",
#         "base_name": "AMERICAN BASE NO.1 INC.",
#         "month": "1",
#         "month_name": "January",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "9162",
#         "unique_dispatched_vehicles": "63",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B02717",
#         "base_name": "ZOOM CAR SERVICE INC.",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "837",
#         "unique_dispatched_vehicles": "3",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B02191",
#         "base_name": "US LIMO SYSTEM INC",
#         "month": "7",
#         "month_name": "July",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "282",
#         "unique_dispatched_vehicles": "11",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B02857",
#         "base_name": "MATHES SERVICE INC.",
#         "dba": "NUNU ROCHDALE CAR SERVICE",
#         "month": "1",
#         "month_name": "January",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1748",
#         "unique_dispatched_vehicles": "7",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B02655",
#         "base_name": "LONG ISLAND CITY CAR AND LIMO INC.",
#         "dba": "A2B CORPORATE SEDAN",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "19",
#         "unique_dispatched_vehicles": "6",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B01717",
#         "base_name": "HIGH CLASS BRONX LIMO C/S CORP",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "14897",
#         "unique_dispatched_vehicles": "90",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B02641",
#         "base_name": "AVENUE X CAR SERVICE INC.",
#         "dba": "PRESTIGE CAR SERVICE",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2375",
#         "unique_dispatched_vehicles": "11",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B00271",
#         "base_name": "UTOG 2-WAY RADIO INC",
#         "dba": "UTOG CORPORATE CAR SERVICE",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "20106",
#         "unique_dispatched_vehicles": "290",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B02308",
#         "base_name": "NORWOOD CAR & LIMO INC.",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "271",
#         "unique_dispatched_vehicles": "24",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B02531",
#         "base_name": "CLEAN AIR CAR SERVICE AND PARKING CORP.",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "5247",
#         "unique_dispatched_vehicles": "38",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B00889",
#         "base_name": "MEXICANA CAR SERVICE INC.",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "4791",
#         "unique_dispatched_vehicles": "19",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B01263",
#         "base_name": "RACHEL'S CAR SERVICE,INC.",
#         "month": "9",
#         "month_name": "September",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "5243",
#         "unique_dispatched_vehicles": "19",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B02671",
#         "base_name": "COMMUNITY CAR SERVICE PRISCILLA CORP",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "3525",
#         "unique_dispatched_vehicles": "19",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B02213",
#         "base_name": "EXPRESS 11 CAR SERVICE, INC.",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "3703",
#         "unique_dispatched_vehicles": "19",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B00095",
#         "base_name": "LIBERTY CAR SERVICE INC.",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "20826",
#         "unique_dispatched_vehicles": "81",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B02917",
#         "base_name": "C & A BLACK CAR CORP.",
#         "month": "7",
#         "month_name": "July",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "207",
#         "unique_dispatched_vehicles": "22",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B00937",
#         "base_name": "RIVERSIDE RADIO DISPATCHER",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "61347",
#         "unique_dispatched_vehicles": "284",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B02472",
#         "base_name": "NEW BUSHWICK LUXURY INC.",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "9379",
#         "unique_dispatched_vehicles": "52",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B02553",
#         "base_name": "NEW JUBILEE CAR SERVICE, INC.",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "5817",
#         "unique_dispatched_vehicles": "53",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B02924",
#         "base_name": "CELEBRITY LUXURY INC.",
#         "month": "9",
#         "month_name": "September",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "6197",
#         "unique_dispatched_vehicles": "55",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B01065",
#         "base_name": "EL BARRIO'S CAR SERVICE LLC",
#         "month": "9",
#         "month_name": "September",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "7579",
#         "unique_dispatched_vehicles": "52",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B02694",
#         "base_name": "CITY LIMOUSINE TRANSPORTATION INC.",
#         "month": "9",
#         "month_name": "September",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "135",
#         "unique_dispatched_vehicles": "16",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B02426",
#         "base_name": "TRISTAR SERVICES (US) INC.",
#         "dba": "TRISTAR WORLDWIDE CHAUFFEURED SERVICES",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1342",
#         "unique_dispatched_vehicles": "26",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B00149",
#         "base_name": "RAINBOW RAD DISP INC",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1677",
#         "unique_dispatched_vehicles": "15",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B02770",
#         "base_name": "CAVALIER CAR & LIMOUSINE, INC.",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "442",
#         "unique_dispatched_vehicles": "8",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B02898",
#         "base_name": "SANO CAR LLC",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2065",
#         "unique_dispatched_vehicles": "15",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B02200",
#         "base_name": "BCL NETWORK LLC",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "613",
#         "unique_dispatched_vehicles": "28",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B01392",
#         "base_name": "NEW AMERICAN CLASS L/C SERVICE CORP.",
#         "month": "6",
#         "month_name": "June",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "190",
#         "unique_dispatched_vehicles": "4",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B01653",
#         "base_name": "ART'S PLACE INC.",
#         "dba": "ON TIME CAR SERVICE",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "3002",
#         "unique_dispatched_vehicles": "14",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B02709",
#         "base_name": "DASH CAR SERVICE CORP",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1056",
#         "unique_dispatched_vehicles": "3",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B00608",
#         "base_name": "SUMMIT CORPORATE CAR INC.",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "988",
#         "unique_dispatched_vehicles": "25",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B01455",
#         "base_name": "REPUBLICA CAR & LIMO SERVICE CORP.",
#         "month": "7",
#         "month_name": "July",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "5590",
#         "unique_dispatched_vehicles": "50",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B00375",
#         "base_name": "THE EXCELLENT C/S INC",
#         "month": "9",
#         "month_name": "September",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "16035",
#         "unique_dispatched_vehicles": "101",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B02102",
#         "base_name": "GOLDEN DRAGON EXPRESS, INC",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "484",
#         "unique_dispatched_vehicles": "6",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B01336",
#         "base_name": "BAY EXPRESS CORP.",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "5173",
#         "unique_dispatched_vehicles": "29",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B02315",
#         "base_name": "LA MORENITA CAR LIMO SERVICE INC",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2330",
#         "unique_dispatched_vehicles": "8",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B02770",
#         "base_name": "CAVALIER CAR & LIMOUSINE, INC.",
#         "month": "7",
#         "month_name": "July",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "234",
#         "unique_dispatched_vehicles": "12",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "b01109",
#         "base_name": "UNITED EXP C/L SVCE",
#         "month": "7",
#         "month_name": "July",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "11705",
#         "unique_dispatched_vehicles": "57",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "LYFT",
#         "base_name": "LYFT",
#         "dba": "LYFT",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1619126",
#         "unique_dispatched_vehicles": "21715",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B01194",
#         "base_name": "440 CAR SERVICE INC.",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1697",
#         "unique_dispatched_vehicles": "7",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B01742",
#         "base_name": "AVALON TRANSPORTATION, LLC",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "332",
#         "unique_dispatched_vehicles": "13",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B02330",
#         "base_name": "OCHO LUXURY CAR, INC.",
#         "dba": "ACAPOLCO EXPRESS",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1064",
#         "unique_dispatched_vehicles": "6",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B01629",
#         "base_name": "BBA MANAGEMENT INC.",
#         "dba": "UNITED CAR & LIMO SERVICE",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2100",
#         "unique_dispatched_vehicles": "12",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B02532",
#         "base_name": "COZY RIDE LIMOUSINE INC",
#         "dba": "COZY TRANSIT",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "401",
#         "unique_dispatched_vehicles": "11",
#         "year": "2020"
#     },
#     {
#         "base_license_number": "B02740",
#         "base_name": "MAZAL LIMOUSINE SERVICE INC",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "182",
#         "unique_dispatched_vehicles": "5",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B02851",
#         "base_name": "GALLANT CAR SERVICE CORP.",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "122",
#         "unique_dispatched_vehicles": "1",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B02346",
#         "base_name": "PIA CAR LIMO. INC.",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "21",
#         "unique_dispatched_vehicles": "2",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B00448",
#         "base_name": "DIAL CAR INC.",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "170",
#         "unique_dispatched_vehicles": "23",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B03018",
#         "base_name": "AUREUS LLC",
#         "dba": "JAVA CAR & LIMOUSINE SERVICE",
#         "month": "8",
#         "month_name": "August",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "27",
#         "unique_dispatched_vehicles": "1",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B00827",
#         "base_name": "CASTLE CAR SERVICE, INC",
#         "month": "8",
#         "month_name": "August",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "756",
#         "unique_dispatched_vehicles": "3",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B01309",
#         "base_name": "ACME LIMOUSINE LLC",
#         "dba": "ARROW TRANSPORTATION",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "352",
#         "unique_dispatched_vehicles": "14",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B02891",
#         "base_name": "GLIDE LUXURY TRANSPORTATION, INC",
#         "month": "7",
#         "month_name": "July",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "21",
#         "unique_dispatched_vehicles": "4",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B01233",
#         "base_name": "NEW LACONIA RAD DISP INC",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "24433",
#         "unique_dispatched_vehicles": "80",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B00652",
#         "base_name": "RESCUE C/S INC",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2017",
#         "unique_dispatched_vehicles": "21",
#         "year": "2020"
#     },
#     {
#         "base_license_number": "UBER",
#         "base_name": "UBER",
#         "dba": "UBER",
#         "month": "8",
#         "month_name": "August",
#         "total_dispatched_shared_trips": "4027450",
#         "total_dispatched_trips": "14060879",
#         "unique_dispatched_vehicles": "72344",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B01726",
#         "base_name": "SUPER CLASS RADIO DISP INC",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "27",
#         "total_dispatched_trips": "7957",
#         "unique_dispatched_vehicles": "57",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B00472",
#         "base_name": "FARRELL'S LEASING CO.",
#         "month": "8",
#         "month_name": "August",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "470",
#         "unique_dispatched_vehicles": "39",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B01721",
#         "base_name": "W.K. CAR & LIMO SERVICE INC",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1574",
#         "unique_dispatched_vehicles": "20",
#         "year": "2020"
#     },
#     {
#         "base_license_number": "B02517",
#         "base_name": "LOS PAISANOS LUXURY C/S INC.",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "648",
#         "unique_dispatched_vehicles": "7",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B03000",
#         "base_name": "ZAPP CAR SERVICE INC.",
#         "month": "1",
#         "month_name": "January",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "27",
#         "unique_dispatched_vehicles": "1",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B02480",
#         "base_name": "WOODHAVEN LIMOUSINE INC",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "834",
#         "unique_dispatched_vehicles": "29",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B00171",
#         "base_name": "CURB TRANSPORTATION SERVICES LLC.",
#         "month": "10",
#         "month_name": "October",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "5002",
#         "unique_dispatched_vehicles": "26",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B01727",
#         "base_name": "CHAUFFEUR SERVICES, INC.",
#         "dba": "NICE GUYS LIMO",
#         "month": "1",
#         "month_name": "January",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "33",
#         "unique_dispatched_vehicles": "2",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B00475",
#         "base_name": "RIDGE TRANSPORTATION CORP.",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "3681",
#         "unique_dispatched_vehicles": "9",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B02627",
#         "base_name": "A PEGASUS LIMOUSINE CORP.",
#         "dba": "APL LIMO",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "129",
#         "unique_dispatched_vehicles": "9",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B02725",
#         "base_name": "KIRIN TRANSPORTATION INC",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1274",
#         "unique_dispatched_vehicles": "23",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B02566",
#         "base_name": "GSL LIMOUSINES CORP.",
#         "month": "10",
#         "month_name": "October",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1300",
#         "unique_dispatched_vehicles": "34",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B01751",
#         "base_name": "CONCORDE EXP OF N.Y. INC",
#         "month": "7",
#         "month_name": "July",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2901",
#         "unique_dispatched_vehicles": "10",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B01742",
#         "base_name": "AVALON TRANSPORTATION, LLC",
#         "month": "6",
#         "month_name": "June",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "694",
#         "unique_dispatched_vehicles": "22",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B02120",
#         "base_name": "HARRISON GLOBAL LLC",
#         "dba": "BOSTON COACH",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "5310",
#         "unique_dispatched_vehicles": "96",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B02962",
#         "base_name": "HEALTH BLACK CAR SERVICES, CORP",
#         "dba": "ADON",
#         "month": "7",
#         "month_name": "July",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "506",
#         "unique_dispatched_vehicles": "6",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B01973",
#         "base_name": "RAJA CAR & LIMOUSINE SERVICE INC.",
#         "dba": "ANGEL CAR SERVICE",
#         "month": "8",
#         "month_name": "August",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1578",
#         "unique_dispatched_vehicles": "11",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B02377",
#         "base_name": "AMERICAN BASE #2. INC.",
#         "month": "8",
#         "month_name": "August",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "398",
#         "unique_dispatched_vehicles": "6",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B01362",
#         "base_name": "AMERICAN BASE NO.1 INC.",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "33767",
#         "unique_dispatched_vehicles": "207",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B00449",
#         "base_name": "A KINGS HWY C/S INC.",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2981",
#         "unique_dispatched_vehicles": "10",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B02306",
#         "base_name": "ACCUELIMO LUXURY LLC",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "3437",
#         "unique_dispatched_vehicles": "26",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B00445",
#         "base_name": "JOE M LEASING CORP",
#         "dba": "FOUR TWO'S PVT C/S",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "7614",
#         "unique_dispatched_vehicles": "21",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B01088",
#         "base_name": "PAISA 2 CAR  AND LIMOUSINE SERVICE INC",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "111",
#         "unique_dispatched_vehicles": "3",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B02655",
#         "base_name": "LONG ISLAND CITY CAR AND LIMO INC.",
#         "dba": "A2B CORPORATE SEDAN",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "735",
#         "unique_dispatched_vehicles": "9",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B02315",
#         "base_name": "LA MORENITA CAR LIMO SERVICE INC",
#         "month": "1",
#         "month_name": "January",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "5946",
#         "unique_dispatched_vehicles": "35",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B00492",
#         "base_name": "BLU-WHITE ASSOCIATED TRANSPORTATION SERVICE INC",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "4959",
#         "unique_dispatched_vehicles": "24",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B01730",
#         "base_name": "LUCKY EXPRESS CORPORATION",
#         "dba": "GOOD LUCK CAR SVCE",
#         "month": "9",
#         "month_name": "September",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "14898",
#         "unique_dispatched_vehicles": "128",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B01318",
#         "base_name": "LOWER EAST SIDE C/S CORP",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "15330",
#         "unique_dispatched_vehicles": "67",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B00449",
#         "base_name": "A KINGS HWY C/S INC.",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2555",
#         "unique_dispatched_vehicles": "11",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B02315",
#         "base_name": "LA MORENITA CAR LIMO SERVICE INC",
#         "month": "6",
#         "month_name": "June",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "4546",
#         "unique_dispatched_vehicles": "21",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B01340",
#         "base_name": "UNICAR COMPANY INC",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "21332",
#         "unique_dispatched_vehicles": "106",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B02021",
#         "base_name": "EASYRIDE CAR SERVICE INC.",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "992",
#         "unique_dispatched_vehicles": "3",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B03022",
#         "base_name": "BLACK CAR EXPRESS.COM CORP",
#         "month": "1",
#         "month_name": "January",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "137",
#         "unique_dispatched_vehicles": "3",
#         "year": "2020"
#     },
#     {
#         "base_license_number": "B01332",
#         "base_name": "SKYWAY CAR SERVICE EXPRESS INC.",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "939",
#         "unique_dispatched_vehicles": "19",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B01069",
#         "base_name": "RPO CAR AND LIMOUSINE SERVICE INC.",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2320",
#         "unique_dispatched_vehicles": "14",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B02925",
#         "base_name": "SIGNATURE BLACK CAR LLC",
#         "month": "8",
#         "month_name": "August",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "4",
#         "unique_dispatched_vehicles": "3",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B01413",
#         "base_name": "SFL INC",
#         "month": "9",
#         "month_name": "September",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1193",
#         "unique_dispatched_vehicles": "43",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B02252",
#         "base_name": "ASIANA LIMOUSINE INC.",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "16",
#         "unique_dispatched_vehicles": "4",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B02833",
#         "base_name": "ADVANCED LUXURY LIMO SVC. INC.",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "3505",
#         "unique_dispatched_vehicles": "19",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B01553",
#         "base_name": "CITY LINE CAR SERVICE INC",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "23285",
#         "unique_dispatched_vehicles": "115",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B01663",
#         "base_name": "CIBAO RADIO DISPATCH",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "3382",
#         "unique_dispatched_vehicles": "24",
#         "year": "2020"
#     },
#     {
#         "base_license_number": "B02470",
#         "base_name": "VAHANA INC.",
#         "month": "10",
#         "month_name": "October",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "624",
#         "unique_dispatched_vehicles": "12",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B01118",
#         "base_name": "INTERNATIONAL CAR SERVICE INC.",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "578",
#         "unique_dispatched_vehicles": "6",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B00375",
#         "base_name": "THE EXCELLENT C/S INC",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "20642",
#         "unique_dispatched_vehicles": "86",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B03110",
#         "base_name": "BETTER CAR & LIMOUSINE SERVICE INC",
#         "dba": "BELTWAY CAR SERVICE",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1",
#         "unique_dispatched_vehicles": "1",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B02874",
#         "base_name": "CAPSTAR CHAUFFEURS,INC.",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "130",
#         "unique_dispatched_vehicles": "9",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B01751",
#         "base_name": "CONCORDE EXP OF N.Y. INC",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "3440",
#         "unique_dispatched_vehicles": "11",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B01300",
#         "base_name": "KENNEDY RAD DISP INC",
#         "month": "10",
#         "month_name": "October",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "9076",
#         "unique_dispatched_vehicles": "78",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B01066",
#         "base_name": "DOMINICANA RAD DISP INC",
#         "month": "7",
#         "month_name": "July",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "5733",
#         "unique_dispatched_vehicles": "41",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B00955",
#         "base_name": "GOLDEN-TOWN CAR & LIMOUSINE SERVICE INC.",
#         "month": "8",
#         "month_name": "August",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "700",
#         "unique_dispatched_vehicles": "26",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B01236",
#         "base_name": "BLS LIMO SVC OF NY INC",
#         "month": "1",
#         "month_name": "January",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2660",
#         "unique_dispatched_vehicles": "110",
#         "year": "2020"
#     },
#     {
#         "base_license_number": "B02133",
#         "base_name": "TWR CAR & LIMO, INC.",
#         "month": "6",
#         "month_name": "June",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "6235",
#         "unique_dispatched_vehicles": "68",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B01066",
#         "base_name": "DOMINICANA RAD DISP INC",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "8699",
#         "unique_dispatched_vehicles": "54",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B00401",
#         "base_name": "TREMONT DISPATCHING CORP",
#         "month": "6",
#         "month_name": "June",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "161",
#         "unique_dispatched_vehicles": "3",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B00965",
#         "base_name": "BEN JEVO MGT. INC.",
#         "dba": "NEWPORT CAR SERVICE",
#         "month": "8",
#         "month_name": "August",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "8713",
#         "unique_dispatched_vehicles": "58",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B01529",
#         "base_name": "J.I.G. TRANSPORT CORP.",
#         "dba": "ECKFORD CAR SERVICE",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1674",
#         "unique_dispatched_vehicles": "11",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "VIA",
#         "base_name": "VIA",
#         "dba": "VIA",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "255655",
#         "unique_dispatched_vehicles": "923",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B02248",
#         "base_name": "HYBRID LIMO EXPRESS INC.",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1557",
#         "unique_dispatched_vehicles": "8",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B01821",
#         "base_name": "EMPIRE TRANSPORTATION SERVICE INC.",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1363",
#         "unique_dispatched_vehicles": "9",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B02229",
#         "base_name": "NEW FAT INC.",
#         "dba": "ELEGANTE",
#         "month": "6",
#         "month_name": "June",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "6856",
#         "unique_dispatched_vehicles": "69",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "UBER",
#         "base_name": "UBER",
#         "dba": "UBER",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2259575",
#         "unique_dispatched_vehicles": "14290",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B00221",
#         "base_name": "PROFESSIONAL CAR SERVICE INC",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "7849",
#         "unique_dispatched_vehicles": "54",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B01777",
#         "base_name": "PREMIUM RADIO DISP & MULTI SVC",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "19934",
#         "unique_dispatched_vehicles": "182",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B00906",
#         "base_name": "OLYMPIA OPERATING CAR SERVICE OF NY CORP.",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1004",
#         "unique_dispatched_vehicles": "6",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B02060",
#         "base_name": "AMERICAN LIMOUSINE LLC",
#         "dba": "FLYTE TYME WORLDWIDE/ADDISON LEE/TRISTAR",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "4197",
#         "unique_dispatched_vehicles": "119",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B02793",
#         "base_name": "SEAVIEW ISLAND CAR SERVICE",
#         "month": "10",
#         "month_name": "October",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "93",
#         "unique_dispatched_vehicles": "1",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B02627",
#         "base_name": "A PEGASUS LIMOUSINE CORP.",
#         "dba": "APL LIMO",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "276",
#         "unique_dispatched_vehicles": "10",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B02912",
#         "base_name": "FIRST CLASS LUXURY INC",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1633",
#         "unique_dispatched_vehicles": "9",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B00369",
#         "base_name": "BOULEVARD OPERATING INC.",
#         "month": "9",
#         "month_name": "September",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "456",
#         "unique_dispatched_vehicles": "9",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B02460",
#         "base_name": "CABOT LIMO NY CORP.",
#         "month": "8",
#         "month_name": "August",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "949",
#         "unique_dispatched_vehicles": "25",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B00021",
#         "base_name": "MEXICANA HIGH CLASS INC.",
#         "dba": "CAPITAL CAR SERVICE",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1309",
#         "unique_dispatched_vehicles": "28",
#         "year": "2020"
#     },
#     {
#         "base_license_number": "B01128",
#         "base_name": "PAK-EAGLE INC.",
#         "dba": "JEWEL CAR SERVICE",
#         "month": "8",
#         "month_name": "August",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "4108",
#         "unique_dispatched_vehicles": "15",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B01391",
#         "base_name": "ROSE 'N' DALE C/S INC",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "430",
#         "unique_dispatched_vehicles": "6",
#         "year": "2020"
#     },
#     {
#         "base_license_number": "B02901",
#         "base_name": "GALLANT LUXURY SERVICE CORP.",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "864",
#         "unique_dispatched_vehicles": "16",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B00991",
#         "base_name": "BLUE LANE CAR SERVICE INC",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "289",
#         "unique_dispatched_vehicles": "12",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B01341",
#         "base_name": "A NEW DAY RAD DISP INC",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "3527",
#         "unique_dispatched_vehicles": "26",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "LYFT",
#         "base_name": "LYFT",
#         "dba": "LYFT",
#         "month": "6",
#         "month_name": "June",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1073973",
#         "unique_dispatched_vehicles": "15095",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B00160",
#         "base_name": "JAFFA CAR & LIMO SVC INC",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "3941",
#         "unique_dispatched_vehicles": "21",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B02855",
#         "base_name": "JUNIORS LUXURY INC",
#         "dba": "MEGA JUNIORS",
#         "month": "10",
#         "month_name": "October",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2147",
#         "unique_dispatched_vehicles": "23",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B02838",
#         "base_name": "THA MAYA CAR SERVICE INC",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "557",
#         "unique_dispatched_vehicles": "12",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B01124",
#         "base_name": "COOPERATIVA CLBNA DE CON INC",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "4083",
#         "unique_dispatched_vehicles": "32",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B02447",
#         "base_name": "LUIGI MEMO INC.",
#         "dba": "VIEW",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "49",
#         "unique_dispatched_vehicles": "14",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B02196",
#         "base_name": "N & T DOUBLE DIAMOND LIMOUSINES, INC.",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "29",
#         "unique_dispatched_vehicles": "4",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B02111",
#         "base_name": "HUANG HOU CAR SERVICES INC.",
#         "dba": "HUANG HOU CAR SERVICES INC.",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
# ...
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B02501",
#         "base_name": "EAST HANOVER AUTO SALES, INC.",
#         "dba": "MY LIMOUSINE SERVICE",
#         "month": "10",
#         "month_name": "October",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "59",
#         "unique_dispatched_vehicles": "9",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B01312",
#         "base_name": "BROOKLYN RAD DISP INC",
#         "month": "9",
#         "month_name": "September",
#         "total_dispatched_shared_trips": "87",
#         "total_dispatched_trips": "3742",
#         "unique_dispatched_vehicles": "26",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B01498",
#         "base_name": "MEGA CAR SVCE CORP",
#         "month": "6",
#         "month_name": "June",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "9533",
#         "unique_dispatched_vehicles": "39",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B00446",
#         "base_name": "COMMUNICAR INCORPORATED",
#         "month": "1",
#         "month_name": "January",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "6006",
#         "unique_dispatched_vehicles": "132",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B01339",
#         "base_name": "R C AUDUBON SVC INC",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "16225",
#         "unique_dispatched_vehicles": "147",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B01200",
#         "base_name": "NEW YORK APPLE CAR SERVICE INC",
#         "dba": "N Y LIMO & CAR SVCE",
#         "month": "6",
#         "month_name": "June",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "5555",
#         "unique_dispatched_vehicles": "27",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B03080",
#         "base_name": "AMBAR TRANSPORTATION INC.",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "4351",
#         "unique_dispatched_vehicles": "59",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B00987",
#         "base_name": "MARLBORO CAR SERVICE INC.",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2337",
#         "unique_dispatched_vehicles": "19",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B02552",
#         "base_name": "INTERSTATE LUXURY LIMOUSINES INC.",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2426",
#         "unique_dispatched_vehicles": "13",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B00457",
#         "base_name": "PREMIUM BRONX CORP",
#         "month": "7",
#         "month_name": "July",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "223",
#         "unique_dispatched_vehicles": "53",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B01406",
#         "base_name": "GOTHAM CAR SERVICE INC.",
#         "dba": "LEGEND CAR SERVICE",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "426",
#         "unique_dispatched_vehicles": "12",
#         "year": "2020"
#     },
#     {
#         "base_license_number": "B02217",
#         "base_name": "PCS LIMOUSINE INC.",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "784",
#         "unique_dispatched_vehicles": "14",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B01328",
#         "base_name": "DV LUXURY CAR SERVICE INC",
#         "dba": "RIDE SAFE CAR SERVICE",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1115",
#         "unique_dispatched_vehicles": "23",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B02491",
#         "base_name": "CALL THREES LLC",
#         "month": "7",
#         "month_name": "July",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "879",
#         "unique_dispatched_vehicles": "6",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B03243",
#         "base_name": "CAPRICE CAR SERVICE NO.2,INC",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2048",
#         "unique_dispatched_vehicles": "15",
#         "year": "2020"
#     },
#     {
#         "base_license_number": "B00210",
#         "base_name": "HOWARD CAR SERVICE,INC.",
#         "month": "9",
#         "month_name": "September",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "133",
#         "unique_dispatched_vehicles": "13",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B01088",
#         "base_name": "PAISA 2 CAR  AND LIMOUSINE SERVICE INC",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "264",
#         "unique_dispatched_vehicles": "6",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B02435",
#         "base_name": "TEINETCO, INC",
#         "month": "1",
#         "month_name": "January",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "152",
#         "unique_dispatched_vehicles": "19",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B01145",
#         "base_name": "ULTRA RADIO DISP INC",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "47039",
#         "unique_dispatched_vehicles": "272",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B00911",
#         "base_name": "RIVERSIDE PLUS RADIO DISPATCH, INC.",
#         "dba": "NEW WEBSTER CAR & LIMO SERVICE",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "14175",
#         "unique_dispatched_vehicles": "90",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B01768",
#         "base_name": "NEW SUPERIOR RADIO GRP CORP",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "4041",
#         "unique_dispatched_vehicles": "32",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B01721",
#         "base_name": "W.K. CAR & LIMO SERVICE INC",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "6623",
#         "unique_dispatched_vehicles": "43",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B02163",
#         "base_name": "JUNIORS EXPRESS CAR SERVICE INC.",
#         "month": "7",
#         "month_name": "July",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1529",
#         "unique_dispatched_vehicles": "13",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B01751",
#         "base_name": "CONCORDE EXP OF N.Y. INC",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "3159",
#         "unique_dispatched_vehicles": "11",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B00227",
#         "base_name": "PARK WEST EXEC. SERVICES, INC.",
#         "dba": "TOWN CARS",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "627",
#         "unique_dispatched_vehicles": "20",
#         "year": "2020"
#     },
#     {
#         "base_license_number": "B03152",
#         "base_name": "EXIT LUXURY INC.",
#         "month": "6",
#         "month_name": "June",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2",
#         "unique_dispatched_vehicles": "1",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B03084",
#         "base_name": "PERSIST CORPORATION",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1431",
#         "unique_dispatched_vehicles": "17",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B03030",
#         "base_name": "Q-FIRST LIMOUSINE CORP.",
#         "month": "8",
#         "month_name": "August",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "123",
#         "unique_dispatched_vehicles": "9",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B00652",
#         "base_name": "RESCUE C/S INC",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "6216",
#         "unique_dispatched_vehicles": "19",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B02942",
#         "base_name": "FANNY RADIO DISPATCHER SERVICE INC.",
#         "month": "10",
#         "month_name": "October",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "865",
#         "unique_dispatched_vehicles": "7",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B02996",
#         "base_name": "FOREVER BLUE CAR SERVICE INC.",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1643",
#         "unique_dispatched_vehicles": "25",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B02797",
#         "base_name": "CJ LIMOUSINE LLC",
#         "month": "10",
#         "month_name": "October",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "433",
#         "unique_dispatched_vehicles": "9",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B01328",
#         "base_name": "DV LUXURY CAR SERVICE INC",
#         "dba": "RIDE SAFE CAR SERVICE",
#         "month": "10",
#         "month_name": "October",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "4215",
#         "unique_dispatched_vehicles": "72",
#         "year": "2018"
#     },
#     {
#         "base_license_number": "B02657",
#         "base_name": "MALCOLM LIMO EXPRESS CORP.",
#         "month": "12",
#         "month_name": "December",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2952",
#         "unique_dispatched_vehicles": "18",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B01109",
#         "base_name": "UNITED EXP C/L SVCE",
#         "month": "2",
#         "month_name": "February",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "8020",
#         "unique_dispatched_vehicles": "43",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B00256",
#         "base_name": "FAST OPERATING CORP",
#         "dba": "CARMEL C/L SVCE",
#         "month": "10",
#         "month_name": "October",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "62748",
#         "unique_dispatched_vehicles": "736",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B02834",
#         "base_name": "811 TRANSIT CORP",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2491",
#         "unique_dispatched_vehicles": "9",
#         "year": "2020"
#     },
#     {
#         "base_license_number": "B02590",
#         "base_name": "LUXOR LIMO INC",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2233",
#         "unique_dispatched_vehicles": "48",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B02975",
#         "base_name": "LI YANG LIMOUSINE INC",
#         "month": "3",
#         "month_name": "March",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "41",
#         "unique_dispatched_vehicles": "20",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B02505",
#         "base_name": "TRELAWNY CAR SERVICE INC",
#         "month": "6",
#         "month_name": "June",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1218",
#         "unique_dispatched_vehicles": "9",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B00039",
#         "base_name": "BERMUDA LIMOUSINE SERVICE INC.",
#         "month": "10",
#         "month_name": "October",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "1158",
#         "unique_dispatched_vehicles": "45",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B00235",
#         "base_name": "ARISTACAR & LIMOUSINE, LTD.",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "540",
#         "unique_dispatched_vehicles": "19",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "LYFT",
#         "base_name": "LYFT",
#         "dba": "LYFT",
#         "month": "11",
#         "month_name": "November",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "450483",
#         "unique_dispatched_vehicles": "7023",
#         "year": "2015"
#     },
#     {
#         "base_license_number": "B02917",
#         "base_name": "C & A BLACK CAR CORP.",
#         "month": "7",
#         "month_name": "July",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "170",
#         "unique_dispatched_vehicles": "25",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B01980",
#         "base_name": "READY TO ROLL TRANSPORTATION, INC.",
#         "month": "1",
#         "month_name": "January",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "681",
#         "unique_dispatched_vehicles": "20",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B01653",
#         "base_name": "ART'S PLACE INC.",
#         "dba": "ON TIME CAR SERVICE",
#         "month": "10",
#         "month_name": "October",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2219",
#         "unique_dispatched_vehicles": "17",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B01273",
#         "base_name": "PUERTO RICO CAR SERVICE INC.",
#         "month": "5",
#         "month_name": "May",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "10092",
#         "unique_dispatched_vehicles": "53",
#         "year": "2017"
#     },
#     {
#         "base_license_number": "B00900",
#         "base_name": "BIG Q CAR SVC. INC.",
#         "month": "10",
#         "month_name": "October",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "52623",
#         "unique_dispatched_vehicles": "198",
#         "year": "2016"
#     },
#     {
#         "base_license_number": "B01146",
#         "base_name": "CHURCH AVE C/S INC",
#         "month": "4",
#         "month_name": "April",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "8494",
#         "unique_dispatched_vehicles": "35",
#         "year": "2019"
#     },
#     {
#         "base_license_number": "B02067",
#         "base_name": "GROUP AMERICAR TRANSPORTATION,LLC.",
#         "month": "10",
#         "month_name": "October",
#         "total_dispatched_shared_trips": "0",
#         "total_dispatched_trips": "2243",
#         "unique_dispatched_vehicles": "62",
#         "year": "2019"
#     }
# ]

# %%
total_uber_months =
