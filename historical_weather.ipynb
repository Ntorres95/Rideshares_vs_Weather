# %%
#dependencies
import requests
import json
import datetime
import numpy as np
import pandas as pd
import os
#from config import api_key
#token = {'token':api_key}

# %%
#need 2 base url's depending on what we need to get
base_url = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/data

#addtional endpoints

#station name
station_name = 'GHCND:USW00094728'
#begin and end date
begin_date = '2015-01-01'
end_date = '2025-12-30'
#loc ID of NY city
locationid = 'FIPS:36'
#for locationcatergoryid possible
location_cat_id = "USW00094728"
#more_params ={'variable':[ 'ddmxt','ddmnt','ddavt','ddbst','ddtst','ddws','ddmxws','ddsr','ddr','dddp','ddwc']}
#daily summary code GHCND
datasetid= 'GHCND'
#start at the earliest date
sortfield='mindate'
base_url_stations = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/stations'
#params = 'datasetid='+str(datasetid)+'&'+'locationcategoryid='+str(location_cat_id)+'&'+'startdate='+str(begin_date)+'&'+'enddate='+str(end_date)+'&'+'limit=25'+'&'+'units=standard'
'https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USC00300958&startdate=2015-01-01&enddate=2015-12-31'

# %%
target_url = base_url+addition
#station url
stations = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/stations?locationid=FIPS:36&limit=1000'
url = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GHCND&datatypeid=TAVG&limit=1000&stationid=GHCND:USC00300958&startdate=2015-01-01&enddate=2015-12-31'
another = 'https://www.ncdc.noaa.gov/cdo-web/api/v2/data?datasetid=GSOM&locationid=FIPS:36&startdate=2015-01-01&enddate=2015-12-30&limit=1000'

# %%
station_data = requests.get(stations,headers=token)

print("Request status code: "+str(weather_data.status_code))
# Out:
# Request status code: 200

# %%
print(station_data.json())
# Out:
# {'metadata': {'resultset': {'offset': 1, 'count': 2321, 'limit': 1000}}, 'results': [{'elevation': 146, 'mindate': '1941-04-01', 'maxdate': '1960-06-01', 'latitude': 41.2, 'name': 'MEAD POND RESERVOIR, NY US', 'datacoverage': 0.9048, 'id': 'COOP:064599', 'elevationUnit': 'METERS', 'longitude': -73.51667}, {'elevation': 4, 'mindate': '1932-01-01', 'maxdate': '1937-05-01', 'latitude': 41.25, 'name': 'OLD GREENWICH, NY US', 'datacoverage': 0.9848, 'id': 'COOP:065984', 'elevationUnit': 'METERS', 'longitude': -73.55}, {'elevation': 121.9, 'mindate': '1947-10-01', 'maxdate': '1950-11-01', 'latitude': 43.9, 'name': 'ADAMS CENTER, NY US', 'datacoverage': 0.8681, 'id': 'COOP:300015', 'elevationUnit': 'METERS', 'longitude': -76.06667}, {'elevation': 195.1, 'mindate': '1965-10-01', 'maxdate': '1972-12-01', 'latitude': 43.81667, 'name': 'ADAMS, NY US', 'datacoverage': 0.9996, 'id': 'COOP:300018', 'elevationUnit': 'METERS', 'longitude': -76.01667}, {'elevation': 304.5, 'mindate': '1931-01-01', 'm
# ...

# %%
test = station_data.json()
station_df = pd.DataFrame.from_dict(test['results'])
#station_df.loc[]
# Out:
#      elevation     mindate     maxdate   latitude                        name  \
# 0        146.0  1941-04-01  1960-06-01  41.200000  MEAD POND RESERVOIR, NY US
# 1          4.0  1932-01-01  1937-05-01  41.250000        OLD GREENWICH, NY US
# 2        121.9  1947-10-01  1950-11-01  43.900000         ADAMS CENTER, NY US
# 3        195.1  1965-10-01  1972-12-01  43.816670                ADAMS, NY US
# 4        304.5  1931-01-01  2015-11-01  42.101300              ADDISON, NY US
# ..         ...         ...         ...        ...                         ...
# 995      397.8  2011-06-01  2012-11-02  42.941370    MORRISVILLE 3.0 N, NY US
# 996      127.7  2011-08-01  2013-12-19  43.082272    CANASTOTA 0.4 ESE, NY US
# 997      285.6  2012-10-01  2013-08-08  43.021400     MUNNSVILLE 3.3 N, NY US
# 998      172.2  2007-02-15  2020-07-20  43.080120        ONEIDA 0.4 NW, NY US
# 999      210.6  2015-03-01  2016-04-01  43.042140      CANASTOTA 3.0 S, NY US
#
# ...

# %%
#set time frame and convert string in dataset
min_time_df = pd.to_datetime('2015-01-01',unit='ns')
max_time_df = pd.to_datetime('2020-12-01',unit='ns')
station_df['mindate'] = pd.to_datetime(station_df['mindate'],unit='ns')
station_df['maxdate'] = pd.to_datetime(station_df['maxdate'],unit='ns')

# %%
filtered station_df.loc
# Out:
#      elevation    mindate    maxdate   latitude                        name  \
# 0        146.0 1941-04-01 1960-06-01  41.200000  MEAD POND RESERVOIR, NY US
# 1          4.0 1932-01-01 1937-05-01  41.250000        OLD GREENWICH, NY US
# 2        121.9 1947-10-01 1950-11-01  43.900000         ADAMS CENTER, NY US
# 3        195.1 1965-10-01 1972-12-01  43.816670                ADAMS, NY US
# 4        304.5 1931-01-01 2015-11-01  42.101300              ADDISON, NY US
# ..         ...        ...        ...        ...                         ...
# 995      397.8 2011-06-01 2012-11-02  42.941370    MORRISVILLE 3.0 N, NY US
# 996      127.7 2011-08-01 2013-12-19  43.082272    CANASTOTA 0.4 ESE, NY US
# 997      285.6 2012-10-01 2013-08-08  43.021400     MUNNSVILLE 3.3 N, NY US
# 998      172.2 2007-02-15 2020-07-20  43.080120        ONEIDA 0.4 NW, NY US
# 999      210.6 2015-03-01 2016-04-01  43.042140      CANASTOTA 3.0 S, NY US
#
# ...

# %%
range_days = pd.date_range(start'1/1/2015',end='7/1/2020')

#for each day from 2015-2019 ...
for day in range_days:
    date = str(day)
    print('working on date:'+year)
    
    #make the api call
    r = requests.get(f'https://api.weathersource.com/v1/{api_key}/postal_codes/{postal_code},{country}/history.json?period=day&{date}T00:00=')
    #load the api response as a json
    d = r.json()
    #get all items in the response which are average temperature readings
    avg_temps = [item for item in d['results'] if item['datatype']=='TAVG']
    #get the date field from all average temperature readings
    dates_temp += [item['date'] for item in avg_temps]
    #get the actual average temperature from all average temperature readings
    temps += [item['value'] for item in avg_temps]

# %%
range_days = pd.date_range(start='1/1/2015',end='7/1/2020')
range_days
# Out:
# DatetimeIndex(['2015-01-01', '2015-01-02', '2015-01-03', '2015-01-04',
#                '2015-01-05', '2015-01-06', '2015-01-07', '2015-01-08',
#                '2015-01-09', '2015-01-10',
#                ...
#                '2020-06-22', '2020-06-23', '2020-06-24', '2020-06-25',
#                '2020-06-26', '2020-06-27', '2020-06-28', '2020-06-29',
#                '2020-06-30', '2020-07-01'],
#               dtype='datetime64[ns]', length=2009, freq='D')
